# %% [markdown]
# # Day 01 — notebook skeleton
#
# This notebook loads `days/input.txt`, inspects the raw input, shows simple parsing strategies, and provides skeleton functions `solve_part1` and `solve_part2` so you can iteratively develop and test solutions for each part.
#
# Run cells in order. If you restart the kernel, re-run the input cell first to reload `lines`.

# %%
import requests
import os

Day = 1

# get file from website using private session key stored in enviromental variables
r = requests.get(
            f'https://adventofcode.com/2025/day/'+str(Day)+'/input',
            cookies={'session': os.getenv('AdventSessionKey')}
)

# read r.text
data = r.text.strip()

# %%
data
# Out:
# 'Puzzle inputs differ by user.  Please log in to get your puzzle input.'
